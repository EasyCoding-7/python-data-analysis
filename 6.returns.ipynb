# %% [markdown]
# ## 디폴트 install, import

# %%
# !pip install finance-datareader
# !pip install beautifulsoup4 
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: finance-datareader in c:\git\python-data-analysis\venv\lib\site-packages (0.9.20)
# Requirement already satisfied: tqdm in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: lxml in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (4.7.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (1.3.5)
# Requirement already satisfied: requests>=2.3.0 in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (2.26.0)
# Requirement already satisfied: requests-file in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pytz>=2017.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\git\python-data-analysis\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: colorama in c:\git\python-data-analysis\venv\lib\site-packages (from tqdm->finance-datareader) (0.4.4)
# Requirement already satisfied: finance-datareader in c:\git\python-data-analysis\venv\lib\site-packages (0.9.20)
# Requirement already satisfied: tqdm in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: lxml in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (4.7.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (1.3.5)
# Requirement already satisfied: requests>=2.3.0 in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (2.26.0)
# Requirement already satisfied: requests-file in c:\git\python-data-analysis\venv\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pytz>=2017.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\git\python-data-analysis\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\python-data-analysis\venv\lib\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: colorama in c:\git\python-data-analysis\venv\lib\site-packages (from tqdm->finance-datareader) (0.4.4)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4 in c:\git\python-data-analysis\venv\lib\site-packages (4.10.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4 in c:\git\python-data-analysis\venv\lib\site-packages (4.10.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: soupsieve>1.2 in c:\git\python-data-analysis\venv\lib\site-packages (from beautifulsoup4) (2.3.1)
#
# Requirement already satisfied: soupsieve>1.2 in c:\git\python-data-analysis\venv\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: numpy in c:\git\python-data-analysis\venv\lib\site-packages (1.21.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\git\python-data-analysis\venv\lib\site-packages (1.21.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\git\python-data-analysis\venv\lib\site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\git\python-data-analysis\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\git\python-data-analysis\venv\lib\site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\git\python-data-analysis\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# default settings
import numpy as np
import pandas as pd
from datetime import datetime

# jupyter notebook 여러 실행인자 실행해도 print되게 만들기
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('max_columns', None)

# %% [markdown]
# ## 6. 수익률 계산

# %%
import FinanceDataReader as fdr

df1 = fdr.DataReader("005930", '2018-01-02', '2018-10-30')
df2 = fdr.DataReader("069500", '2018-01-02', '2018-10-30')
df = pd.concat([df1['Close'], df2['Close']], axis=1)
df.columns = ['삼성전자', 'KODEX 200']
df.head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  51020      30317
# 2018-01-03  51620      30446
# 2018-01-04  51080      30206
# 2018-01-05  52120      30616
# 2018-01-08  52020      30822
#              삼성전자  KODEX 200
# Date
# 2018-01-02  51020      30317
# 2018-01-03  51620      30446
# 2018-01-04  51080      30206
# 2018-01-05  52120      30616
# 2018-01-08  52020      30822

# %% [markdown]
# 수익률의 계산을 위해 dataframe `shift()` 써보기

# %%
# 데이터를 한 칸 아래로 내린다
df.shift()
# Out:
#                 삼성전자  KODEX 200
# Date
# 2018-01-02       NaN        NaN
# 2018-01-03 51020.000  30317.000
# 2018-01-04 51620.000  30446.000
# 2018-01-05 51080.000  30206.000
# 2018-01-08 52120.000  30616.000
# ...              ...        ...
# 2018-10-24 43050.000  25636.000
# 2018-10-25 42550.000  25504.000
# 2018-10-26 41000.000  25097.000
# 2018-10-29 41000.000  24699.000
# 2018-10-30 41400.000  24499.000
#
# [202 rows x 2 columns]
#                 삼성전자  KODEX 200
# Date
# 2018-01-02       NaN        NaN
# 2018-01-03 51020.000  30317.000
# 2018-01-04 51620.000  30446.000
# 2018-01-05 51080.000  30206.000
# 2018-01-08 52120.000  30616.000
# ...              ...        ...
# 2018-10-24 43050.000  25636.000
# 2018-10-25 42550.000  25504.000
# 2018-10-26 41000.000  25097.000
# 2018-10-29 41000.000  24699.000
# 2018-10-30 41400.000  24499.000
#
# [202 rows x 2 columns]

# %%
df.shift(periods=1).head()
# Out:
#                 삼성전자  KODEX 200
# Date
# 2018-01-02       NaN        NaN
# 2018-01-03 51020.000  30317.000
# 2018-01-04 51620.000  30446.000
# 2018-01-05 51080.000  30206.000
# 2018-01-08 52120.000  30616.000
#                 삼성전자  KODEX 200
# Date
# 2018-01-02       NaN        NaN
# 2018-01-03 51020.000  30317.000
# 2018-01-04 51620.000  30446.000
# 2018-01-05 51080.000  30206.000
# 2018-01-08 52120.000  30616.000

# %%
# 초 단위로 내릴 수 있음.
df.shift(1, freq="S").head()
# Out:
#                       삼성전자  KODEX 200
# Date
# 2018-01-02 00:00:01  51020      30317
# 2018-01-03 00:00:01  51620      30446
# 2018-01-04 00:00:01  51080      30206
# 2018-01-05 00:00:01  52120      30616
# 2018-01-08 00:00:01  52020      30822
#                       삼성전자  KODEX 200
# Date
# 2018-01-02 00:00:01  51020      30317
# 2018-01-03 00:00:01  51620      30446
# 2018-01-04 00:00:01  51080      30206
# 2018-01-05 00:00:01  52120      30616
# 2018-01-08 00:00:01  52020      30822

# %%
df.head()
df.shift().head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  51020      30317
# 2018-01-03  51620      30446
# 2018-01-04  51080      30206
# 2018-01-05  52120      30616
# 2018-01-08  52020      30822
#              삼성전자  KODEX 200
# Date
# 2018-01-02  51020      30317
# 2018-01-03  51620      30446
# 2018-01-04  51080      30206
# 2018-01-05  52120      30616
# 2018-01-08  52020      30822
#                 삼성전자  KODEX 200
# Date
# 2018-01-02       NaN        NaN
# 2018-01-03 51020.000  30317.000
# 2018-01-04 51620.000  30446.000
# 2018-01-05 51080.000  30206.000
# 2018-01-08 52120.000  30616.000
#                 삼성전자  KODEX 200
# Date
# 2018-01-02       NaN        NaN
# 2018-01-03 51020.000  30317.000
# 2018-01-04 51620.000  30446.000
# 2018-01-05 51080.000  30206.000
# 2018-01-08 52120.000  30616.000

# %%
# 이렇게 하면 수익률을 계산할 수 있겠지?
(df / df.shift() - 1).head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02    NaN        NaN
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02    NaN        NaN
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007

# %% [markdown]
# 좀 더 간단하게 `pct_change()`를 써볼까?

# %%
# 위와 정확히 동일하다
df.pct_change(periods=1).head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02    NaN        NaN
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02    NaN        NaN
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007

# %%
df.pct_change(periods=2).head()
# Out:
#             삼성전자  KODEX 200
# Date
# 2018-01-02   NaN        NaN
# 2018-01-03   NaN        NaN
# 2018-01-04 0.001     -0.004
# 2018-01-05 0.010      0.006
# 2018-01-08 0.018      0.020
#             삼성전자  KODEX 200
# Date
# 2018-01-02   NaN        NaN
# 2018-01-03   NaN        NaN
# 2018-01-04 0.001     -0.004
# 2018-01-05 0.010      0.006
# 2018-01-08 0.018      0.020

# %%
# 뭐 대략 이런식으로 쓰이겠지??
simple_rtn_df = df.pct_change().fillna(0)
simple_rtn_df.head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007

# %% [markdown]
# log단위로 수익률이 필요하다면?

# %%
# numpy와 함께라면 쉽다
np.log(df / df.shift()).head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02    NaN        NaN
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.011     -0.008
# 2018-01-05  0.020      0.013
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02    NaN        NaN
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.011     -0.008
# 2018-01-05  0.020      0.013
# 2018-01-08 -0.002      0.007

# %%
log_rtn_df = np.log(df / df.shift()).fillna(0)
log_rtn_df.head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.011     -0.008
# 2018-01-05  0.020      0.013
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.011     -0.008
# 2018-01-05  0.020      0.013
# 2018-01-08 -0.002      0.007

# %% [markdown]
# ## 그래프로 그려보자

# %%
# !pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in c:\git\python-data-analysis\venv\lib\site-packages (0.11.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in c:\git\python-data-analysis\venv\lib\site-packages (0.11.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Git\python-data-analysis\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas>=0.23 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\git\python-data-analysis\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
#
# Requirement already satisfied: pandas>=0.23 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\git\python-data-analysis\venv\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\git\python-data-analysis\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\git\python-data-analysis\venv\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\git\python-data-analysis\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
log_rtn_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
log_rtn_df.hist(bins=50, sharex=True)
# Out:
# array([[<AxesSubplot:title={'center':'삼성전자'}>,
#         <AxesSubplot:title={'center':'KODEX 200'}>]], dtype=object)
# array([[<AxesSubplot:title={'center':'삼성전자'}>,
#         <AxesSubplot:title={'center':'KODEX 200'}>]], dtype=object)

# %%
log_rtn_df.boxplot()
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.distplot(log_rtn_df['KODEX 200'], kde=False, bins=50);
sns.distplot(log_rtn_df['삼성전자'], kde=False, bins=50);
# Out:
# C:\Git\python-data-analysis\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Git\python-data-analysis\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(log_rtn_df);
# Out:
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 누적 수익률 계산해 보기

# %%
df.head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  51020      30317
# 2018-01-03  51620      30446
# 2018-01-04  51080      30206
# 2018-01-05  52120      30616
# 2018-01-08  52020      30822
#              삼성전자  KODEX 200
# Date
# 2018-01-02  51020      30317
# 2018-01-03  51620      30446
# 2018-01-04  51080      30206
# 2018-01-05  52120      30616
# 2018-01-08  52020      30822

# %%
df.iloc[0]
# Out:
# 삼성전자         51020
# KODEX 200    30317
# Name: 2018-01-02 00:00:00, dtype: int64
# 삼성전자         51020
# KODEX 200    30317
# Name: 2018-01-02 00:00:00, dtype: int64

# %%
cum_rtn_df = df / df.iloc[0]
cum_rtn_df.head()
# Out:
#             삼성전자  KODEX 200
# Date
# 2018-01-02 1.000      1.000
# 2018-01-03 1.012      1.004
# 2018-01-04 1.001      0.996
# 2018-01-05 1.022      1.010
# 2018-01-08 1.020      1.017
#             삼성전자  KODEX 200
# Date
# 2018-01-02 1.000      1.000
# 2018-01-03 1.012      1.004
# 2018-01-04 1.001      0.996
# 2018-01-05 1.022      1.010
# 2018-01-08 1.020      1.017

# %%
simple_rtn_df.head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.010     -0.008
# 2018-01-05  0.020      0.014
# 2018-01-08 -0.002      0.007

# %%
cum_rtn_df = (1 + simple_rtn_df).cumprod()
cum_rtn_df.head()
# Out:
#             삼성전자  KODEX 200
# Date
# 2018-01-02 1.000      1.000
# 2018-01-03 1.012      1.004
# 2018-01-04 1.001      0.996
# 2018-01-05 1.022      1.010
# 2018-01-08 1.020      1.017
#             삼성전자  KODEX 200
# Date
# 2018-01-02 1.000      1.000
# 2018-01-03 1.012      1.004
# 2018-01-04 1.001      0.996
# 2018-01-05 1.022      1.010
# 2018-01-08 1.020      1.017

# %% [markdown]
# log로 표현

# %%
log_rtn_df.head()
# Out:
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.011     -0.008
# 2018-01-05  0.020      0.013
# 2018-01-08 -0.002      0.007
#              삼성전자  KODEX 200
# Date
# 2018-01-02  0.000      0.000
# 2018-01-03  0.012      0.004
# 2018-01-04 -0.011     -0.008
# 2018-01-05  0.020      0.013
# 2018-01-08 -0.002      0.007

# %%
cum_rtn_df = np.exp(log_rtn_df.cumsum())
cum_rtn_df.head()
# Out:
#             삼성전자  KODEX 200
# Date
# 2018-01-02 1.000      1.000
# 2018-01-03 1.012      1.004
# 2018-01-04 1.001      0.996
# 2018-01-05 1.022      1.010
# 2018-01-08 1.020      1.017
#             삼성전자  KODEX 200
# Date
# 2018-01-02 1.000      1.000
# 2018-01-03 1.012      1.004
# 2018-01-04 1.001      0.996
# 2018-01-05 1.022      1.010
# 2018-01-08 1.020      1.017

# %% [markdown]
# 시각화

# %%
cum_rtn_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Git\python-data-analysis\venv\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
